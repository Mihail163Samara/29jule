# %% [markdown]
# <a href="https://colab.research.google.com/github/Mihail163Samara/29jule/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Untitled4_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1.
#
# 1. Скачать данные по ссылке
# https://www.kaggle.com/datasets/ionaskel/laptop-prices
#
# 2. Считать данные с помощью pandas
#
# 3. Вывести на экран первые 5 строк
#
# 4. Создать новый признак Cpu_Company, который будет
# содержать только название фирмы, которая произвела CPU
#
# 5. Создать новый признак Memory_Amount, который будет
# содержать только количество Gb памяти без указания типа
# носителя
#
# 6. Создать новый признак Memory_Type, который будет
# содержать только тип носителя (HDD/SDD/др.)
#
# 7. Удалите признаки Memory и ScreenResolution

# %%
import pandas as pd
df = pd.read_csv("laptops.csv", sep=';')
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# ...

# %%
df['Cpu_Company'] = df ['Cpu'].apply(lambda x: x.split()[0])
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# ...

# %%
def convert(x):
  memory = x.split()[0]
  if memory.endswith('GB'):
    res = memory.replace('GB','')
  elif memory.endswith('TB'):
    res = float(memory.replace('TB', '')) * 1024
  return int(res)

df['Memory_Amount'] = df['Memory'].apply(lambda x: convert(x))
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# ...

# %%
def convert(x):
  return x.replace(' ', '').split('B')[-1]
df['Memory_Type'] = df['Memory'].apply(lambda x: convert(x))
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# ...

# %%
df.drop(columns=['Memory', 'ScreenResolution'], inplace=True)
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94       Intel
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00       Intel
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# ...

# %% [markdown]
# ## Задание 2.
#
# 1. Создайте признак SSD, который изначально равен 0
#
# 2. Поставьте в признаке SSD 1, если ноутбук
# действительно с типом носителя SSD
#
# 3. Уберите в признаке Weight значения 'kg' и поменяйте его
# тип данных на вещественный

# %%
df['SSD'] = 0
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94       Intel
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00       Intel
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60       Intel
#
#    Memory_Amount   Memory_Type  SSD
# 0            128           SSD    0
# ...

# %%
df.loc[df['Memory_Type'] == 'SSD', 'SSD'] = 1
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94       Intel
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00       Intel
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60       Intel
#
#    Memory_Amount   Memory_Type  SSD
# 0            128           SSD    1
# ...

# %%
df['Weight'] = df['Weight'].apply(lambda x: x.replace('kg', ''))
df['Weight'] = df['Weight'].astype('float')
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type  SSD
# 0            128           SSD    1
# ...

# %% [markdown]
# # Задание 3.
# Создайте датафрейм с клиентами:
#
# clients = pd.DataFrame({
# 'client_id': [45, 32, 67, 33, 43],
# 'laptop_id': [506, 398, 710, 120, 1999]
# })
#
# laptop_id - это индексы датафрейма с ноутбуками
#
# 1. Присоедините к таблице clients данные по ноутбукам
# через метод join
#
# 2. Присоедините к таблице clients данные по ноутбукам
# через метод merge
#
# Это нужно, чтобы понимать, какие ноутбуки покупались клиентами

# %%
clients = pd.DataFrame({ 'client_id': [45, 32, 67, 33, 43], 'laptop_id': [506, 398, 710, 120, 1999] })


clients_lap_id = clients.set_index('laptop_id')
clients_lap_id
# Out:
#            client_id
# laptop_id
# 506               45
# 398               32
# 710               67
# 120               33
# 1999              43

# %%
joined = clients_lap_id.join(df)
joined
# Out:
#            client_id Company                 Product     TypeName  Inches  \
# laptop_id
# 506               45    Asus  ZenBook UX510UX-CN211T     Notebook    15.6
# 398               32    Dell         Precision M5520  Workstation    15.6
# 710               67  Lenovo      Legion Y520-15IKBN       Gaming    15.6
# 120               33    Acer                  Spin 3     Notebook    15.6
# 1999              43     NaN                     NaN          NaN     NaN
#
#                                    Cpu  Ram                         Gpu  \
# laptop_id
# 506         Intel Core i7 7500U 2.7GHz  8GB       Intel HD Graphics 620
# 398        Intel Core i7 7700HQ 2.8GHz  8GB         Nvidia Quadro M1200
# 710        Intel Core i7 7700HQ 2.8GHz  8GB  Nvidia GeForce GTX 1050 Ti
# 120         Intel Core i3 7100U 2.4GHz  6GB       Intel HD Graphics 620
# 1999                               NaN  NaN                         NaN
#
# ...

# %%
df['laptop_id'] = df.index
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
merged = clients.merge(df, on='laptop_id')
merged
# Out:
#    client_id  laptop_id Company                 Product     TypeName  Inches  \
# 0         45        506    Asus  ZenBook UX510UX-CN211T     Notebook    15.6
# 1         32        398    Dell         Precision M5520  Workstation    15.6
# 2         67        710  Lenovo      Legion Y520-15IKBN       Gaming    15.6
# 3         33        120    Acer                  Spin 3     Notebook    15.6
#
#                            Cpu  Ram                         Gpu       OpSys  \
# 0   Intel Core i7 7500U 2.7GHz  8GB       Intel HD Graphics 620  Windows 10
# 1  Intel Core i7 7700HQ 2.8GHz  8GB         Nvidia Quadro M1200  Windows 10
# 2  Intel Core i7 7700HQ 2.8GHz  8GB  Nvidia GeForce GTX 1050 Ti  Windows 10
# 3   Intel Core i3 7100U 2.4GHz  6GB       Intel HD Graphics 620  Windows 10
#
#    Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD
# 0    2.00       1224.0       Intel            256         HDD    0
# ...

# %% [markdown]
# ##Задание 4.
#
# Составьте несколько сводных таблиц
#
# 4.1 Найдите среднюю стоимость ноутбуков в зависимости
# от компании производителя
#
# Отсортируйте от меньшей стоимости к большей
#
# 4.2 Найдите минимальную, среднюю и максимальную
# стоимости ноутбуков в зависимости от производителя
# процессора
#
# 4.3 Постройте таблицу с подсчетом количества ноутбуков в
# данных в зависимости от производителя CPU и ОЗУ
#
# 4.4 Постройте таблицу с подсчетом средней стоимости
# ноутбуков в данных в зависимости от операционной
# системы и GB памяти

# %%
df.groupby('Company').agg({'Price_euros': 'mean'}).sort_values('Price_euros', ascending=False)
# Out:
#            Price_euros
# Company
# Razer      3346.142857
# LG         2099.000000
# MSI        1728.908148
# Google     1677.666667
# Microsoft  1612.308333
# Apple      1564.198571
# Huawei     1424.000000
# Samsung    1413.444444
# Toshiba    1267.812500
# Dell       1186.068990
# Xiaomi     1133.462500
# Asus       1104.169367
# Lenovo     1086.384444
# HP         1067.774854
# Fujitsu     729.000000
# Acer        626.775825
# Chuwi       314.296667
# Mediacom    295.000000
# Vero        217.425000

# %%
df.groupby('Cpu_Company').agg({'Price_euros': ['mean','max','min']})
# Out:
#              Price_euros
#                     mean     max    min
# Cpu_Company
# AMD           560.638871  2199.0  199.0
# Intel        1152.214145  6099.0  174.0
# Samsung       659.000000   659.0  659.0

# %%
df.pivot_table(index='Cpu_Company', columns = 'Ram', values='Weight', aggfunc ='count', fill_value = 0 )
# Out:
# Ram          12GB  16GB  24GB  2GB  32GB  4GB  64GB  6GB  8GB
# Cpu_Company
# AMD             2     3     0    1     0   31     0   13   12
# Intel          23   197     3   21    17  343     1   28  607
# Samsung         0     0     0    0     0    1     0    0    0

# %%
df.groupby(['OpSys', 'Memory_Amount']).agg({'Price_euros': 'mean'}).unstack('Memory_Amount')
# Out:
#               Price_euros                                               \
# Memory_Amount        8       16          32          64           128
# OpSys
# Android               NaN     NaN         NaN  434.000000          NaN
# Chrome OS             NaN  305.38  412.454545  774.333333  1275.000000
# Linux                 NaN     NaN         NaN         NaN   742.250000
# Mac OS X              NaN     NaN         NaN         NaN  1099.000000
# No OS                 NaN     NaN         NaN         NaN   562.140000
# Windows 10         2249.0     NaN  270.001471  499.716000  1026.489167
# Windows 10 S          NaN     NaN         NaN  308.995000  1039.000000
# Windows 7             NaN     NaN         NaN         NaN  1320.323333
# macOS                 NaN     NaN         NaN         NaN  1119.315000
#
#                                                                              \
# Memory_Amount    180     240          256         500     508          512
# OpSys
# ...

# %% [markdown]
# ##Задание 5*
#
# Ответьте на несколько вопросов
#
# 5.1 Ноутбуков каких компаний и с каким процессором
# больше?
#
# 5.2 С каким типом памяти и с каким объемом памяти
# больше ноутбуков?

# %%
pd.crosstab(index=df['Company'], columns=df['Cpu_Company'])
# Out:
# Cpu_Company  AMD  Intel  Samsung
# Company
# Acer          10     93        0
# Apple          0     21        0
# Asus          11    147        0
# Chuwi          0      3        0
# Dell           0    297        0
# Fujitsu        0      3        0
# Google         0      3        0
# HP            25    249        0
# Huawei         0      2        0
# LG             0      3        0
# Lenovo        16    281        0
# MSI            0     54        0
# Mediacom       0      7        0
# Microsoft      0      6        0
# Razer          0      7        0
# Samsung        0      8        1
# Toshiba        0     48        0
# Vero           0      4        0
# Xiaomi         0      4        0

# %%
pd.crosstab(index=df['Memory_Type'], columns=df['Memory_Amount'])
# Out:
# Memory_Amount  8     16    32    64    128   180   240   256   500   508   \
# Memory_Type
# FlashStorage      0     7    38    15     4     0     0     8     0     0
# HDD               0     0     1     1    97     0     0    85   132     0
# Hybrid            0     0     0     0     0     0     0     1     0     1
# SSD               1     3     6     1    76     5     1   414     0     0
#
# Memory_Amount  512   1024  2048
# Memory_Type
# FlashStorage      2     0     0
# HDD              17   227    16
# Hybrid            1     9     0
# SSD             120    14     0

# %%
df.to_csv('laptops_2.csv')
